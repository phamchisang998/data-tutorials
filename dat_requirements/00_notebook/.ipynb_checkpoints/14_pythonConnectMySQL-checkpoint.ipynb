# %%
# "mysql+pymysql://dattran:password@localhost/agents"
from sqlalchemy import create_engine
import pandas as pd

host = 'localhost'
port = 3306
user = 'dattran'
pwd = 'password'
db_name = 'agents'

connect_string = f"mysql+pymysql://{user}:{pwd}@{host}:{port}/{db_name}"

engine = create_engine(connect_string)
conn = engine.connect()


pd.read_sql("select * from agents", conn)
# Out:
#    AGENT_CODE                                AGENT_NAME  \
# 0      A007    Ramasundar
# 1      A003    Alex
# 2      A008    Alford
# 3      A011    Ravi Kumar
# 4      A010    Santakumar
# 5      A012    Lucida
# 6      A005    Anderson
# 7      A001    Subbarao
# 8      A002    Mukesh
# 9      A006    McDen
# 10     A004    Ivan
# 11     A009    Benjamin
#
#                            WORKING_AREA  COMMISSION         PHONE_NO COUNTRY
# 0   Bangalore                                  0.15  077-25814763         \r
# 1   London                                     0.13  075-12458969         \r
# 2   New York                                   0.12  044-25874365         \r
# 3   Bangalore                                  0.15  077-45625874         \r
# 4   Chennai                                    0.14  007-22388644         \r
# 5   San Jose                                   0.12  044-52981425         \r
# 6   Brisban                                    0.13  045-21447739         \r
# 7   Bangalore                                  0.14  077-12346674         \r
# 8   Mumbai                                     0.11  029-12358964         \r
# 9   London                                     0.15  078-22255588         \r
# 10  Torento                                    0.15  008-22544166         \r
# 11  Hampshair                                  0.11  008-22536178         \r

# %%
import pandas as pd

pd.read_csv("../01_data/05_examWriterResult_2.csv")
# Out:
#          product_name  order_id  price  amount   total
# 0              coffee         1  15000       5   75000
# 1                milk         2  20000       7  140000
# 2               latte         3  17000       3   51000
# 3         mango juice         3  21000       2   42000
# 4         fresh water         4  10000      10  100000
# 5        freeze latte         5  19000       5   95000
# 6        orange juice         5  18000       6  108000
# 7    sugar cane juice         5   5000       1    5000
# 8            milk tea         6  25000       7  175000
# 9             coconut         9  15000      11  165000
# 10          cold brew         9  30000       2   60000
# 11        lemon juice        10  11000       5   55000
# 12  water melon juice        11  18000       7  126000
# 13         kiwi juice        11  21000       5  105000

# %%
# !pip install -r '../00_dat_requirements.txt'
