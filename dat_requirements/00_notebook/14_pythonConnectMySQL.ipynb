# %%
# "mysql+pymysql://dattran:password@localhost/agents"
from sqlalchemy import create_engine
import pandas as pd

host = 'localhost'
port = 3306
user = 'dattran'
pwd = 'password'
db_name = 'agents'

connect_string = f"mysql+pymysql://{user}:{pwd}@{host}:{port}/{db_name}"

engine = create_engine(connect_string)
conn = engine.connect()


pd.read_sql("select * from agents", conn)
# Out:
#    AGENT_CODE                                AGENT_NAME  \
# 0      A007    Ramasundar
# 1      A003    Alex
# 2      A008    Alford
# 3      A011    Ravi Kumar
# 4      A010    Santakumar
# 5      A012    Lucida
# 6      A005    Anderson
# 7      A001    Subbarao
# 8      A002    Mukesh
# 9      A006    McDen
# 10     A004    Ivan
# 11     A009    Benjamin
#
#                            WORKING_AREA  COMMISSION         PHONE_NO COUNTRY
# 0   Bangalore                                  0.15  077-25814763         \r
# 1   London                                     0.13  075-12458969         \r
# 2   New York                                   0.12  044-25874365         \r
# 3   Bangalore                                  0.15  077-45625874         \r
# 4   Chennai                                    0.14  007-22388644         \r
# 5   San Jose                                   0.12  044-52981425         \r
# 6   Brisban                                    0.13  045-21447739         \r
# ...

# %%
csv_df = pd.read_csv("../01_data/05_examWriterResult_2.csv")
csv_df.to_sql('agents_2', conn, if_exists='replace')
# Out:
# 14

# %%
pd.read_sql("select product_name,amount from agents_2", conn)
# Out:
#          product_name  amount
# 0              coffee       5
# 1                milk       7
# 2               latte       3
# 3         mango juice       2
# 4         fresh water      10
# 5        freeze latte       5
# 6        orange juice       6
# 7    sugar cane juice       1
# 8            milk tea       7
# 9             coconut      11
# 10          cold brew       2
# 11        lemon juice       5
# 12  water melon juice       7
# 13         kiwi juice       5

# %%
# !pip install -r '../00_dat_requirements.txt'
