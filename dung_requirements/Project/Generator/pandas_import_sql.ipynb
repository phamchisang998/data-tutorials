# %%
import re
import glob
import pandas as pd 
from pandasql import sqldf
#import library
import pandas as pd 
import json
from pandasql import sqldf
from sqlalchemy import create_engine

# %%
#Connect database
connection_string = 'mysql+pymysql://minhdung:020920@localhost/School'

engine = create_engine(connection_string)

conn = engine.connect()

# %%
def filter_files(file_name):
    pattern = '([^.]*)(10A|11B|12C)([0-9]{1}|[0-9]{2}).json'
    return bool(re.search(pattern, file_name))


class_name_pattern = '(10|11|12)A([0-9]*)'
folder_path = "../Generator/Data/**/*.json"

def extract_score(df,scores):
    for key,value in scores.items():
        df[key] = value
    return None

for item in filter(filter_files, glob.glob(folder_path, recursive = True)):
    class_name_index = re.search(class_name_pattern, item).span()
    class_name = item[class_name_index[0]:class_name_index[1]]
    df = pd.read_json(item)
    df['class name'] = class_name
    df1 = pd.json_normalize(df['Score'], max_level=0)
    df = pd.concat([df.drop(columns = 'Score'), df1], axis=0)
    df.to_sql('LeQuyDon_students', conn, if_exists= 'append')
# Out:
#     School ID  Class ID   average    rank class name      Math    Physic  \
# 0        45.0       0.0  3.896658    weak       10A8       NaN       NaN
# 1        45.0       1.0  7.521086  medium       10A8       NaN       NaN
# 2        45.0       2.0  0.090840    weak       10A8       NaN       NaN
# 3        45.0       3.0  6.963646  medium       10A8       NaN       NaN
# 4        45.0       4.0  0.666066    weak       10A8       NaN       NaN
# ..        ...       ...       ...     ...        ...       ...       ...
# 31        NaN       NaN       NaN     NaN        NaN  3.926456  4.083371
# 32        NaN       NaN       NaN     NaN        NaN  5.385965  5.386409
# 33        NaN       NaN       NaN     NaN        NaN  9.961936  9.951151
# 34        NaN       NaN       NaN     NaN        NaN  8.004724  7.834739
# 35        NaN       NaN       NaN     NaN        NaN  5.136642  5.137290
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 31   3.926474    3.738906  3.926456    3.880698  3.926321   3.926455
# 32   8.412223    5.198277  4.699800    5.386059  5.385921   5.315325
# 33   9.961989    9.970201  9.961872    9.961909  9.961873   9.961873
# 34   7.826532    7.826476  7.814425    7.826399  6.588652   7.826532
# 35   5.166493    5.643775  5.136744    3.031116  5.139810   6.210688
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 31      3.926465  4.002960
# 32      5.385552  3.303682
# 33      9.964051  9.961873
# 34      8.890304  7.826538
# 35      5.627813  5.136708
#
# [72 rows x 15 columns]
#     School ID  Class ID  rank   average class name      Math    Physic  \
# 0        31.0       0.0  good  8.802172      10A13       NaN       NaN
# 1        31.0       1.0  weak  0.180905      10A13       NaN       NaN
# 2        31.0       2.0  weak  4.988158      10A13       NaN       NaN
# 3        31.0       3.0  good  9.142616      10A13       NaN       NaN
# 4        31.0       4.0  weak  3.157254      10A13       NaN       NaN
# ..        ...       ...   ...       ...        ...       ...       ...
# 26        NaN       NaN   NaN       NaN        NaN  4.699473  7.286900
# 27        NaN       NaN   NaN       NaN        NaN  9.825863  9.869708
# 28        NaN       NaN   NaN       NaN        NaN  6.538774  6.540002
# 29        NaN       NaN   NaN       NaN        NaN  6.714237  6.731081
# 30        NaN       NaN   NaN       NaN        NaN  8.432118  8.432138
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 26   5.087436    4.845895  4.699473    4.699580  4.702296   1.124714
# 27   9.869694    9.869700  9.868699    9.869733  9.869700   9.869714
# 28   6.335079    8.494563  6.540005    5.745701  6.540004   6.540007
# 29   8.537171    6.731792  6.726158    6.317519  6.671940   5.424859
# 30   8.481525    8.880903  8.438061    7.988282  8.437495   8.432137
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 26      5.134310  4.714653
# 27      9.914661  9.869529
# 28      5.585670  6.540209
# 29      6.731371  6.731790
# 30      8.432918  8.365795
#
# [62 rows x 15 columns]
#     School ID  Class ID    rank   average class name      Math    Physic  \
# 0        14.0       0.0  medium  7.419443      10A16       NaN       NaN
# 1        14.0       1.0  medium  7.689193      10A16       NaN       NaN
# 2        14.0       2.0    weak  4.863909      10A16       NaN       NaN
# 3        14.0       3.0    weak  1.388556      10A16       NaN       NaN
# 4        14.0       4.0  medium  7.754376      10A16       NaN       NaN
# ..        ...       ...     ...       ...        ...       ...       ...
# 28        NaN       NaN     NaN       NaN        NaN  7.985029  6.788263
# 29        NaN       NaN     NaN       NaN        NaN  4.920726  4.914603
# 30        NaN       NaN     NaN       NaN        NaN  9.111543  9.111547
# 31        NaN       NaN     NaN       NaN        NaN  7.576072  7.630632
# 32        NaN       NaN     NaN       NaN        NaN  4.389381  3.547996
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 28   5.857691    6.787174  6.741741    6.788253  6.356934   7.003024
# 29   4.947738    4.947742  4.175398    7.058632  4.002994   4.814909
# 30   9.096234    9.111547  9.431655    9.119876  9.110047   9.074800
# 31   7.630632    7.630651  7.546908    7.630637  7.648523   7.630632
# 32   4.475081    4.389381  4.413861    4.389380  4.711669   4.389284
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 28      6.786162  6.788263
# 29      4.826696  4.867980
# 30      9.111547  8.836674
# 31      7.679598  7.702038
# 32      4.380317  4.807457
#
# [66 rows x 15 columns]
#     School ID  Class ID  rank   average class name      Math    Physic  \
# 0        34.0       0.0  good  8.656457      10A12       NaN       NaN
# 1        34.0       1.0  weak  1.665393      10A12       NaN       NaN
# 2        34.0       2.0  good  9.546169      10A12       NaN       NaN
# 3        34.0       3.0  good  8.150764      10A12       NaN       NaN
# 4        34.0       4.0  good  8.366479      10A12       NaN       NaN
# ..        ...       ...   ...       ...        ...       ...       ...
# 28        NaN       NaN   NaN       NaN        NaN  3.618879  8.317352
# 29        NaN       NaN   NaN       NaN        NaN  8.522943  8.527041
# 30        NaN       NaN   NaN       NaN        NaN  8.901448  8.899552
# 31        NaN       NaN   NaN       NaN        NaN  4.755804  4.167435
# 32        NaN       NaN   NaN       NaN        NaN  7.674997  7.675520
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 28   4.660326    5.171310  2.805873    3.469098  4.660325   4.579430
# 29   8.474631    8.474675  8.411462    8.474675  8.405879   7.690776
# 30   8.392226    8.899552  8.899553    9.323877  8.975401   8.898577
# 31   4.749891    4.749516  5.384471    4.750067  4.749671   4.751209
# 32   7.910621    7.701971  7.675702    7.952423  7.745078   7.675472
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 28      4.660324  4.660324
# 29      8.477767  9.286896
# 30      8.905674  8.899660
# 31      4.687581  4.749516
# 32      7.675319  7.067620
#
# [66 rows x 15 columns]
#     School ID  Class ID    rank   average class name      Math    Physic  \
# 0        55.0       0.0    good  8.002701       10A1       NaN       NaN
# 1        55.0       1.0    good  9.377819       10A1       NaN       NaN
# 2        55.0       2.0  medium  6.931314       10A1       NaN       NaN
# 3        55.0       3.0    weak  4.843834       10A1       NaN       NaN
# 4        55.0       4.0    good  8.303868       10A1       NaN       NaN
# ..        ...       ...     ...       ...        ...       ...       ...
# 29        NaN       NaN     NaN       NaN        NaN  6.515529  6.514489
# 30        NaN       NaN     NaN       NaN        NaN  5.564053  6.700076
# 31        NaN       NaN     NaN       NaN        NaN  9.009823  9.010828
# 32        NaN       NaN     NaN       NaN        NaN  9.376123  5.642523
# 33        NaN       NaN     NaN       NaN        NaN  4.549715  4.974344
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 29   6.142935    7.078291  6.321936    6.515567  6.547975   6.515586
# 30   5.567860    4.990481  5.392582    5.567868  5.567860   5.557639
# 31   9.003533    9.034210  9.009823    8.976083  9.010073   9.043975
# 32   5.548757    5.642503  5.642503    5.640325  4.682240   3.837383
# 33   4.975215    5.100059  5.016138    4.977958  4.974159   5.220995
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 29      6.515591  6.488011
# 30      5.567877  5.202300
# 31      9.009823  8.990060
# 32      4.676628  5.736041
# 33      4.974788  4.978191
#
# [68 rows x 15 columns]
#     School ID  Class ID   average    rank class name      Math    Physic  \
# 0        51.0       0.0  0.545482    weak       10A4       NaN       NaN
# 1        51.0       1.0  6.986264  medium       10A4       NaN       NaN
# 2        51.0       2.0  8.165431    good       10A4       NaN       NaN
# 3        51.0       3.0  5.413470    weak       10A4       NaN       NaN
# 4        51.0       4.0  7.317332  medium       10A4       NaN       NaN
# ..        ...       ...       ...     ...        ...       ...       ...
# 27        NaN       NaN       NaN     NaN        NaN  4.646201  4.645845
# 28        NaN       NaN       NaN     NaN        NaN  8.366230  8.456661
# 29        NaN       NaN       NaN     NaN        NaN  4.294509  5.522461
# 30        NaN       NaN       NaN     NaN        NaN  9.915213  9.918578
# 31        NaN       NaN       NaN     NaN        NaN  4.941500  4.970188
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 27   4.647305    6.728597  4.834160    4.648514  4.646144   4.645847
# 28   8.425383    8.272403  8.458955    8.365837  7.857643   8.365834
# 29   5.714797    4.294524  4.308912    4.295711  4.294509   4.333124
# 30   9.918578    9.918578  9.918578    9.918616  9.919178   9.919814
# 31   4.941548    7.557283  4.941520    2.306183  4.941500   4.940415
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 27      2.370399  4.645442
# 28      8.723539  8.365878
# 29      2.221899  3.664646
# 30      9.918579  9.920068
# 31      5.032866  4.841995
#
# [64 rows x 15 columns]
#     School ID  Class ID   average  rank class name      Math    Physic  \
# 0        54.0       0.0  4.285252  weak       10A2       NaN       NaN
# 1        54.0       1.0  9.440757  good       10A2       NaN       NaN
# 2        54.0       2.0  2.671446  weak       10A2       NaN       NaN
# 3        54.0       3.0  1.264095  weak       10A2       NaN       NaN
# 4        54.0       4.0  3.554111  weak       10A2       NaN       NaN
# ..        ...       ...       ...   ...        ...       ...       ...
# 29        NaN       NaN       NaN   NaN        NaN  4.105426  6.523144
# 30        NaN       NaN       NaN   NaN        NaN  2.039311  2.771087
# 31        NaN       NaN       NaN   NaN        NaN  8.433538  9.723228
# 32        NaN       NaN       NaN   NaN        NaN  5.959954  5.993952
# 33        NaN       NaN       NaN   NaN        NaN  5.195484  5.264049
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 29   8.609155    6.696506  6.523021    6.525880  6.523161   6.523765
# 30   2.039319    2.103338  2.046703    2.031325  2.039323   1.289441
# 31   8.433390    8.433550  8.433526    8.429595  7.385425   8.440843
# 32   5.867295    5.953355  5.984864    8.036036  5.953355   5.953441
# 33   5.505687    5.274236  6.104268    5.214783  5.194080   5.202085
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 29      6.541543  6.658608
# 30      2.084163  1.949178
# 31      8.405351  8.217062
# 32      5.964896  3.866389
# 33      5.194152  3.792692
#
# [68 rows x 15 columns]
#     School ID  Class ID    rank   average class name      Math    Physic  \
# 0        37.0       0.0  medium  7.793635      10A10       NaN       NaN
# 1        37.0       1.0  medium  7.345116      10A10       NaN       NaN
# 2        37.0       2.0    good  9.614353      10A10       NaN       NaN
# 3        37.0       3.0    weak  4.282149      10A10       NaN       NaN
# 4        37.0       4.0  medium  7.714277      10A10       NaN       NaN
# ..        ...       ...     ...       ...        ...       ...       ...
# 29        NaN       NaN     NaN       NaN        NaN  6.362394  7.481350
# 30        NaN       NaN     NaN       NaN        NaN  6.776508  5.346530
# 31        NaN       NaN     NaN       NaN        NaN  8.144590  8.164320
# 32        NaN       NaN     NaN       NaN        NaN  7.166004  6.975578
# 33        NaN       NaN     NaN       NaN        NaN  3.543969  4.049496
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 29   6.348567    5.883653  6.340382    6.364793  6.642097   6.362392
# 30   5.346498    5.370087  5.344559    5.151327  4.086229   5.346513
# 31   8.145175    8.275108  8.186806    7.520647  8.157671   8.201416
# 32   7.174470    7.174332  7.174488    7.151819  7.200959   7.174490
# 33   3.800003    3.959213  5.411526    4.051640  4.038831   4.051405
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 29      6.361834  5.476477
# 30      5.343858  5.352874
# 31      8.144576  8.505451
# 32      7.330839  7.221925
# 33      4.045686  3.564632
#
# [68 rows x 15 columns]
#     School ID  Class ID   average    rank class name      Math    Physic  \
# 0        52.0       0.0  1.764316    weak       10A3       NaN       NaN
# 1        52.0       1.0  7.155430  medium       10A3       NaN       NaN
# 2        52.0       2.0  6.278132    weak       10A3       NaN       NaN
# 3        52.0       3.0  9.475694    good       10A3       NaN       NaN
# 4        52.0       4.0  5.172147    weak       10A3       NaN       NaN
# ..        ...       ...       ...     ...        ...       ...       ...
# 28        NaN       NaN       NaN     NaN        NaN  8.262230  8.903326
# 29        NaN       NaN       NaN     NaN        NaN  5.404129  5.488383
# 30        NaN       NaN       NaN     NaN        NaN  7.987385  8.875434
# 31        NaN       NaN       NaN     NaN        NaN  9.215977  9.215980
# 32        NaN       NaN       NaN     NaN        NaN  7.647861  8.092186
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 28   8.945703    8.947549  9.584487    8.947303  8.945703   9.044281
# 29   5.405683    4.659415  5.404128    5.476639  5.466851   5.404649
# 30   7.971472    8.003552  7.996351    7.165263  8.003553   8.002130
# 31   9.211325    9.215980  8.988600    9.215980  9.215980   9.262381
# 32   8.269723    8.272402  9.079904    8.272685  8.272916   8.272673
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 28      8.947549  8.947357
# 29      5.927512  5.403891
# 30      8.026827  8.003552
# 31      9.197127  9.420472
# 32      8.273190  8.273181
#
# [66 rows x 15 columns]
#     School ID  Class ID   average  rank class name      Math    Physic  \
# 0        48.0       0.0  6.443218  weak       10A5       NaN       NaN
# 1        48.0       1.0  4.400505  weak       10A5       NaN       NaN
# 2        48.0       2.0  4.177008  weak       10A5       NaN       NaN
# 3        48.0       3.0  1.726476  weak       10A5       NaN       NaN
# 4        48.0       4.0  8.710634  good       10A5       NaN       NaN
# ..        ...       ...       ...   ...        ...       ...       ...
# 28        NaN       NaN       NaN   NaN        NaN  6.461215  6.602770
# 29        NaN       NaN       NaN   NaN        NaN  5.255179  4.499480
# 30        NaN       NaN       NaN   NaN        NaN  2.346346  2.348231
# 31        NaN       NaN       NaN   NaN        NaN  5.170903  8.215311
# 32        NaN       NaN       NaN   NaN        NaN  3.386459  2.198966
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 28   6.530183    6.232226  6.467166    6.878533  6.041389   6.476411
# 29   4.499480    4.511510  4.499728    3.339598  4.499480   4.768682
# 30   1.356126    2.348749  6.403254    2.360528  2.514666  -0.535180
# 31   5.781703    5.775855  4.007308    5.781423  5.773286   5.747893
# 32   2.245632    2.620574  2.611467    2.611467  2.582642   2.611467
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 28      6.461182  6.461077
# 29      4.622180  4.499484
# 30      2.348231  1.991354
# 31      5.781705  5.781674
# 32      2.611462  2.634538
#
# [66 rows x 15 columns]
#     School ID  Class ID   average    rank class name      Math    Physic  \
# 0         8.0       0.0  4.965431    weak      10A18       NaN       NaN
# 1         8.0       1.0  5.686510    weak      10A18       NaN       NaN
# 2         8.0       2.0  6.688993  medium      10A18       NaN       NaN
# 3         8.0       3.0  3.282495    weak      10A18       NaN       NaN
# 4         8.0       4.0  9.085563    good      10A18       NaN       NaN
# ..        ...       ...       ...     ...        ...       ...       ...
# 27        NaN       NaN       NaN     NaN        NaN  0.769996  0.798758
# 28        NaN       NaN       NaN     NaN        NaN  0.745965  1.193139
# 29        NaN       NaN       NaN     NaN        NaN  5.963650  5.942164
# 30        NaN       NaN       NaN     NaN        NaN  5.255940  5.131836
# 31        NaN       NaN       NaN     NaN        NaN  9.087488  9.069084
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 27   0.801985    0.830909 -1.449639    4.006870  0.641565   0.801983
# 28  -1.066747    0.746135  0.748281    0.746012  0.754764   0.991461
# 29   5.954295    5.942173  5.886854    5.942165  5.942165   5.942165
# 30   5.116904    5.116896  9.181176    0.630386  5.116897   5.274868
# 31   9.095301    9.095300  9.095300    9.211277  8.825266   9.000746
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 27      0.015435  0.801985
# 28      0.397516  2.203078
# 29      5.944612  5.961402
# 30      5.121661  5.222392
# 31      9.380180  9.093070
#
# [64 rows x 15 columns]
#     School ID  Class ID    rank   average class name      Math    Physic  \
# 0        35.0       0.0  medium  6.838481      10A11       NaN       NaN
# 1        35.0       1.0    good  9.146545      10A11       NaN       NaN
# 2        35.0       2.0    weak  6.085461      10A11       NaN       NaN
# 3        35.0       3.0  medium  7.250948      10A11       NaN       NaN
# 4        35.0       4.0    weak  0.117966      10A11       NaN       NaN
# ..        ...       ...     ...       ...        ...       ...       ...
# 29        NaN       NaN     NaN       NaN        NaN  4.468250  6.001634
# 30        NaN       NaN     NaN       NaN        NaN  5.265992  5.670002
# 31        NaN       NaN     NaN       NaN        NaN  0.483352  0.278329
# 32        NaN       NaN     NaN       NaN        NaN  6.306265  6.306221
# 33        NaN       NaN     NaN       NaN        NaN  8.914948  9.146712
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 29   5.982618    5.982435  5.982243    7.143003  6.115072   5.982243
# 30   5.850659    5.839505  5.669953    5.669953  5.659398   5.674341
# 31  -1.755918    3.638740  0.548937    0.574588  0.333407   0.526836
# 32   6.306226    7.784936  4.071826    6.301261  6.327308   7.038484
# 33   9.145586    9.461172  9.148762    9.146613  9.127122   9.084975
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 29      5.949061  6.215871
# 30      5.725832  5.673896
# 31      0.572066  0.546426
# 32      6.306223  6.313457
# 33      9.146558  9.144673
#
# [68 rows x 15 columns]
#     School ID  Class ID    rank   average class name      Math    Physic  \
# 0        15.0       0.0  medium  7.638080      10A15       NaN       NaN
# 1        15.0       1.0    weak  2.165359      10A15       NaN       NaN
# 2        15.0       2.0  medium  7.948736      10A15       NaN       NaN
# 3        15.0       3.0    weak  4.868889      10A15       NaN       NaN
# 4        15.0       4.0  medium  6.831807      10A15       NaN       NaN
# ..        ...       ...     ...       ...        ...       ...       ...
# 30        NaN       NaN     NaN       NaN        NaN  3.393532  0.324858
# 31        NaN       NaN     NaN       NaN        NaN  5.759533  7.718208
# 32        NaN       NaN     NaN       NaN        NaN  7.850860  8.374139
# 33        NaN       NaN     NaN       NaN        NaN  9.928084  9.839524
# 34        NaN       NaN     NaN       NaN        NaN  7.948386  8.024059
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 30   3.589727    3.748954  3.695664    3.738043  3.750660   3.738484
# 31   7.638735    7.638735  7.642389    7.638735  9.388703   7.684745
# 32   8.494758    8.359528  8.374136    8.374064  8.344450   8.821542
# 33   9.875587    9.859627  9.875606    9.875604  9.876013   9.873761
# 34   8.024464    8.187944  8.024059    7.935723  8.024133   8.023697
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 30      3.747188  7.779485
# 31      7.638754  7.638814
# 32      8.374055  8.373937
# 33      9.875604  9.876630
# 34      8.024066  8.024059
#
# [70 rows x 15 columns]
#     School ID  Class ID    rank   average class name      Math    Physic  \
# 0        22.0       0.0  medium  7.494275      10A14       NaN       NaN
# 1        22.0       1.0  medium  7.553514      10A14       NaN       NaN
# 2        22.0       2.0    good  8.116536      10A14       NaN       NaN
# 3        22.0       3.0  medium  7.694662      10A14       NaN       NaN
# 4        22.0       4.0    weak  0.948793      10A14       NaN       NaN
# ..        ...       ...     ...       ...        ...       ...       ...
# 26        NaN       NaN     NaN       NaN        NaN  8.543077  8.356213
# 27        NaN       NaN     NaN       NaN        NaN  9.206573  9.185422
# 28        NaN       NaN     NaN       NaN        NaN  0.885757  0.886738
# 29        NaN       NaN     NaN       NaN        NaN  1.413789  1.410907
# 30        NaN       NaN     NaN       NaN        NaN  7.922255  7.922254
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 26   8.342163    8.349584  8.400340    8.342852  9.414508   8.342162
# 27   9.222647    9.204375  9.213034    9.215339  9.207057   9.206607
# 28   0.886677    0.751039  1.996721    0.875796  0.073348   0.582380
# 29   1.410905    2.925497 -2.480471    2.756279  2.301173   1.410905
# 30   8.086494    8.301754  7.922254    7.923204  7.495598   7.918197
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 26      6.988551  8.342161
# 27      9.204375  9.178284
# 28      0.886632  1.042294
# 29      1.548867  1.411199
# 30      7.922254  7.808272
#
# [62 rows x 15 columns]
#     School ID  Class ID   average    rank class name      Math    Physic  \
# 0        40.0       0.0  2.546472    weak       10A9       NaN       NaN
# 1        40.0       1.0  7.108808  medium       10A9       NaN       NaN
# 2        40.0       2.0  6.961249  medium       10A9       NaN       NaN
# 3        40.0       3.0  5.595702    weak       10A9       NaN       NaN
# 4        40.0       4.0  2.155960    weak       10A9       NaN       NaN
# ..        ...       ...       ...     ...        ...       ...       ...
# 30        NaN       NaN       NaN     NaN        NaN  5.498885  6.245158
# 31        NaN       NaN       NaN     NaN        NaN  9.154394  9.165602
# 32        NaN       NaN       NaN     NaN        NaN  3.113266  4.565654
# 33        NaN       NaN       NaN     NaN        NaN  3.723619  3.717092
# 34        NaN       NaN       NaN     NaN        NaN  5.170753  5.170713
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 30   4.644274    5.450468  5.397738    5.504039  5.498805   5.751831
# 31   9.113402    9.113388  9.113399    9.113399  9.113397   9.050678
# 32   2.958349    2.956050  3.662356    2.956051  2.956049   2.956235
# 33   3.718519    3.724027  3.724046    3.574221  4.668557   6.192819
# 34   5.197670    5.172484  2.886415    5.170867  5.939428   6.626131
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 30      5.499142  5.497639
# 31      9.113399  9.082931
# 32      0.577236  2.859257
# 33      0.509200  3.688364
# 34      5.170713  5.201954
#
# [70 rows x 15 columns]
#     School ID  Class ID   average    rank class name      Math    Physic  \
# 0        47.0       0.0  4.443345    weak       10A6       NaN       NaN
# 1        47.0       1.0  0.053021    weak       10A6       NaN       NaN
# 2        47.0       2.0  3.558743    weak       10A6       NaN       NaN
# 3        47.0       3.0  7.782018  medium       10A6       NaN       NaN
# 4        47.0       4.0  9.724428    good       10A6       NaN       NaN
# ..        ...       ...       ...     ...        ...       ...       ...
# 26        NaN       NaN       NaN     NaN        NaN  9.886786  9.884845
# 27        NaN       NaN       NaN     NaN        NaN  6.499506  6.250844
# 28        NaN       NaN       NaN     NaN        NaN  8.252379  9.031488
# 29        NaN       NaN       NaN     NaN        NaN  5.655348  2.770182
# 30        NaN       NaN       NaN     NaN        NaN  6.755196  6.758244
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 26   9.885598    9.885596  9.885598    9.884548  9.885598   9.928643
# 27   4.562153    6.453429  6.253227    7.373878  6.250550   6.257589
# 28   8.580762    8.580460  8.976502    8.580678  8.580463   7.973438
# 29   5.713440    5.713001  7.292306    5.713440  5.713118   5.703585
# 30   6.748862    6.785167  6.762319    6.758244  6.758244   6.789194
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 26      9.880455  9.848310
# 27      6.461854  6.142471
# 28      8.579214  8.669218
# 29      5.750982  7.109001
# 30      6.705672  6.761295
#
# [62 rows x 15 columns]
#     School ID  Class ID    rank   average class name      Math    Physic  \
# 0        10.0       0.0    good  8.323878      10A17       NaN       NaN
# 1        10.0       1.0  medium  6.737081      10A17       NaN       NaN
# 2        10.0       2.0  medium  6.938580      10A17       NaN       NaN
# 3        10.0       3.0    weak  3.009880      10A17       NaN       NaN
# 4        10.0       4.0  medium  6.649223      10A17       NaN       NaN
# ..        ...       ...     ...       ...        ...       ...       ...
# 27        NaN       NaN     NaN       NaN        NaN  5.668121  6.433969
# 28        NaN       NaN     NaN       NaN        NaN  5.523495  5.872631
# 29        NaN       NaN     NaN       NaN        NaN  5.046772  5.119001
# 30        NaN       NaN     NaN       NaN        NaN  4.177140  4.171342
# 31        NaN       NaN     NaN       NaN        NaN  7.378145  7.394684
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 27   5.696010    5.673703  5.696101    5.433747  5.696125   5.696125
# 28   5.867638    5.837312  5.752051    5.884144  5.867634   4.801518
# 29   5.045975    4.222051  5.036025    5.045906  5.592736   5.312253
# 30   4.176248    4.113985  1.919628    3.919656  5.727756   4.303650
# 31   6.831598    7.379618  7.377394    7.378143  7.378174   7.250502
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 27      5.419794  5.547557
# 28      8.708207  4.561708
# 29      4.991648  5.045283
# 30      4.163475  5.098605
# 31      7.823472  7.590007
#
# [64 rows x 15 columns]
#     School ID  Class ID    rank   average class name      Math    Physic  \
# 0         3.0       0.0  medium  7.664401      10A20       NaN       NaN
# 1         3.0       1.0    good  8.598670      10A20       NaN       NaN
# 2         3.0       2.0    weak  1.989777      10A20       NaN       NaN
# 3         3.0       3.0    weak  5.868284      10A20       NaN       NaN
# 4         3.0       4.0    good  8.844015      10A20       NaN       NaN
# ..        ...       ...     ...       ...        ...       ...       ...
# 29        NaN       NaN     NaN       NaN        NaN  9.173425  9.157323
# 30        NaN       NaN     NaN       NaN        NaN  5.991176  6.050739
# 31        NaN       NaN     NaN       NaN        NaN  6.040483  5.024504
# 32        NaN       NaN     NaN       NaN        NaN  8.374418  8.577072
# 33        NaN       NaN     NaN       NaN        NaN  7.465539  7.268002
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 29   9.157323    9.167598  8.568466    9.225961  9.157306   9.161046
# 30   6.050739    6.050791  4.966220    6.075215  6.756008   6.362727
# 31   5.972432    5.966456  6.033473    5.943992  7.514657   6.055116
# 32   8.434854    8.427217  8.434262    8.429415  8.431851   8.434826
# 33   7.448695    7.534541  7.465539    7.611846  7.465514   7.465539
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 29      9.647327  9.157455
# 30      6.090995  6.112781
# 31      5.944934  6.055116
# 32      8.434051  8.370576
# 33      7.464637  7.465539
#
# [68 rows x 15 columns]
#     School ID  Class ID    rank   average class name      Math    Physic  \
# 0        46.0       0.0  medium  7.547688       10A7       NaN       NaN
# 1        46.0       1.0    weak  4.714387       10A7       NaN       NaN
# 2        46.0       2.0  medium  7.070707       10A7       NaN       NaN
# 3        46.0       3.0    weak  4.024388       10A7       NaN       NaN
# 4        46.0       4.0    good  8.910976       10A7       NaN       NaN
# ..        ...       ...     ...       ...        ...       ...       ...
# 30        NaN       NaN     NaN       NaN        NaN  4.348171  4.410909
# 31        NaN       NaN     NaN       NaN        NaN  1.345336  1.348401
# 32        NaN       NaN     NaN       NaN        NaN  5.994642  5.944156
# 33        NaN       NaN     NaN       NaN        NaN  8.090737  8.090721
# 34        NaN       NaN     NaN       NaN        NaN  8.818929  7.900323
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 30   4.348201    4.348606  4.348171    4.348185  4.284953   4.348171
# 31   1.400289    1.350017  1.199316    1.274278  1.253384   1.349942
# 32   6.011153    5.993580  6.745562    5.993580  5.314265   5.994808
# 33   8.090737    8.014530  8.155899    8.090686  8.561687   7.900842
# 34   8.769273    8.770143  8.642560    8.773432  8.775267   8.769635
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 30      4.348171  4.348171
# 31     -1.382266  4.361542
# 32      6.004377  5.939675
# 33      8.354032  7.557503
# 34      8.809945  9.663221
#
# [70 rows x 15 columns]
#     School ID  Class ID  rank   average class name      Math    Physic  \
# 0         5.0       0.0  good  8.275397      10A19       NaN       NaN
# 1         5.0       1.0  weak  2.120765      10A19       NaN       NaN
# 2         5.0       2.0  weak  3.826074      10A19       NaN       NaN
# 3         5.0       3.0  good  9.401026      10A19       NaN       NaN
# 4         5.0       4.0  good  9.056430      10A19       NaN       NaN
# ..        ...       ...   ...       ...        ...       ...       ...
# 30        NaN       NaN   NaN       NaN        NaN  8.259536  8.028274
# 31        NaN       NaN   NaN       NaN        NaN  6.648390  6.648557
# 32        NaN       NaN   NaN       NaN        NaN  1.649072  2.257561
# 33        NaN       NaN   NaN       NaN        NaN  1.951943  1.941966
# 34        NaN       NaN   NaN       NaN        NaN  2.957800  0.097355
#
#     Chemistry  Literature   History  Geographic   English  Technique  \
# 0         NaN         NaN       NaN         NaN       NaN        NaN
# 1         NaN         NaN       NaN         NaN       NaN        NaN
# 2         NaN         NaN       NaN         NaN       NaN        NaN
# 3         NaN         NaN       NaN         NaN       NaN        NaN
# 4         NaN         NaN       NaN         NaN       NaN        NaN
# ..        ...         ...       ...         ...       ...        ...
# 30   7.959648    8.026097  8.028280    8.027407  8.028280   8.030194
# 31   6.779818    6.603754  7.565688    6.343927  6.029546   6.570537
# 32   1.649077    3.676828 -1.669068    1.649195  1.542954   1.649210
# 33   1.948203    3.208083  1.950525    1.942073  2.107734   2.331431
# 34   0.861639    0.862960  0.875218    0.861770 -1.414102   0.861493
#
#     Common Sense  Computer
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 30      7.866869  8.028216
# 31      6.648777  6.648777
# 32      2.413996  1.671948
# 33      1.957993  0.179478
# 34      1.960421  0.691833
#
# [70 rows x 15 columns]
